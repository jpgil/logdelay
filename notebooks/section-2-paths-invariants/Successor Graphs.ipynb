# %% [markdown]
# # Successor Graphs

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append("../../src")
# %reload_ext autoreload
# %autoreload 2
from helpers import graph
from path_invariants import *

# %% [markdown]
# ## Successor Graph Example

# %% [markdown]
# Below are the successor graphs of $A=abca$

# %%
A="abca"
sgA=successor_graph(A)

graph( sgA, filename="figures/successor_graph_abca.png")

# %%
A="ABCD"
sgA=successor_graph(A)

graph( sgA, filename="figures/successor_graph_abca.png")

# %% [markdown]
# $|r \overset{T}{\rightarrow} s|$ are the weight of the edge $(r,s)$ in the graph

# %%
sgA["a"]["a"]["weight"], sgA["a"]["b"]["weight"], sgA["a"]["b"]["weight"]
# Out:
# (3, 1, 1)

# %% [markdown]
# ## Adding Successor Graphs

# %%
A="abca"     ; sgA=successor_graph(A)
B="jk"; sgB=successor_graph(B)
J=add_graphs( sgA, sgB)

graph(J, filename="figures/adding_successor_graphs.png")
