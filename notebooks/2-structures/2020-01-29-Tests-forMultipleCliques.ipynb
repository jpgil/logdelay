# %% [markdown]
# # Test Battery for Clique Detection in Multiple Traces

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from functions_2020_01_29 import *

# %%
# Parameters
METHOD_ID="2020-01-25 loop"
PAIRS_ID="all"

# %%
import sys
import logging
logging.basicConfig(format='%(funcName)s:%(levelname)s:%(message)s', level=logging.WARN, stream=sys.stdout)

# %% [markdown]
# ## Tested examples

# %%
# Type 76 ... Failing
T = [
    list("123123ABCABCABC")
#     list("ABCABCABC123123")
]
g, b = evaluate_against(T, ("ABC", "123") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('1', '2', '3'): 2.0, ('A', 'B', 'C'): 3.0, ('3', 'A', 'B', 'C'): 3.0, ('2', 'A', 'B', 'C'): 3.0, ('1', 'A', 'B', 'C'): 3.0}
#
# These 1 paths were correctly detected (1 undetected):
# ['2: 123']
#
# These 3 paths are spurious:
# ['3: 3ABC', '3: 2ABC', '3: 1ABC']

# %% [markdown]
# ## Single Trace Examples

# %%
T = [
    list("ABCABCABCABC"),
]
g, b = evaluate_against(T, ["ABC"] )
# Out:
# Loops found:
# {('A', 'B', 'C'): 4.0}
#
# These 1 paths were correctly detected (0 undetected):
# ['4: ABC']
#
# These 0 paths are spurious:
# []

# %%
T = [
    list("ABCDABCD"),
]
g, b = evaluate_against(T, ["ABCD"] )
# Out:
# Loops found:
# {('A', 'B', 'C', 'D'): 2.0}
#
# These 1 paths were correctly detected (0 undetected):
# ['2: ABCD']
#
# These 0 paths are spurious:
# []

# %%
T = [
    list("1234ABCDABCDxyz"),
]
g, b = evaluate_against(T, ["ABCD", "1234xyz"] )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('A', 'B', 'C', 'D'): 2.0}
#
# These 1 paths were correctly detected (1 undetected):
# ['1: 1234xyz']
#
# These 7 paths are spurious:
# ['2: ABCDy', '2: 3ABCD', '2: ABCDx', '2: 2ABCD', '2: ABCDz', '2: 4ABCD', '2: 1ABCD']

# %%
# Type 75
T = [
    list("ABC1231A2B3C1ABC23vwxy"),
]
g, b = evaluate_against(T, ("ABC", "123", "vwxy") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('1', '2', '3'): 3.0, ('A', 'B', '3'): 3.0, ('A', '2', '3'): 3.0, ('A', 'B', 'C'): 3.0}
#
# These 1 paths were correctly detected (2 undetected):
# ['1: vwxy']
#
# These 16 paths are spurious:
# ['3: AB3y', '3: AB3x', '3: AB3w', '3: AB3v', '3: 123y', '3: 123x', '3: 123w', '3: 123v', '3: A23y', '3: A23x', '3: A23w', '3: A23v', '3: ABCy', '3: ABCx', '3: ABCw', '3: ABCv']

# %%
# Type 77
T = [
    list("aAb1B2cd3Cefgh1iAjk2Blmnop3qCrst1AuBC2vwxy3z"),
]
g, b = evaluate_against(T, ("ABC", "123", "abcdefghijklmnopqrstuvwxyz") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('A', 'B', '3'): 3.0, ('1', 'B', '3'): 3.0, ('A', 'B', 'C'): 3.0, ('1', 'B', 'C'): 3.0, ('A', '2', '3'): 3.0, ('1', '2', '3'): 3.0}
#
# These 1 paths were correctly detected (2 undetected):
# ['1: abcdefghijklmnopqrstuvwxyz']
#
# These 37 paths are spurious:
# ['3: 1u', '3: Au', '3: 1BCy', '3: a1BC', '3: 1BCx', '3: b1BC', '3: 1BCw', '3: 1BCz', '3: 1BCv', '3: ABCy', '3: aABC', '3: ABCx', '3: ABCw', '3: ABCz', '3: ABCv', '3: cC', '3: dC', '3: b1B3', '3: 1B3z', '3: a1B3', '3: AB3z', '3: aAB3', '3: b123', '3: 123z', '3: a123', '3: A23z', '3: aA23', '3: c3', '3: d3', '3: 12y', '3: 12x', '3: 12w', '3: 12v', '3: A2y', '3: A2x', '3: A2w', '3: A2v']

# %%
# Type 78
T = [
    list(".1A.B2.C3..ABC...A1..2B..3C.123")
]
g, b = evaluate_against(T, ("ABC", "123") )
# Out:
# Loops found:
# {('B', '2'): 3.0, ('A', 'B', 'C'): 3.0, ('1', '2', '3'): 3.0, ('C', '3'): 3.0, ('A', '1'): 3.0}
#
# These 2 paths were correctly detected (0 undetected):
# ['3: 123', '3: ABC']
#
# These 3 paths are spurious:
# ['3: C3', '3: B2', '3: A1']

# %%
"""
head_with_loop = 123 ABCD* efg*

12 @ABCD @ef
"""
T = [
    list("123ABCDefgABCDABCDefgefgefg"),
]
g, b = evaluate_against(T, ("ABCD", "123", "efg") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('e', 'f', 'g'): 4.0, ('A', 'B', 'C', 'D'): 3.0, ('D', 'e', 'f', 'g'): 4.0, ('B', 'e', 'f', 'g'): 4.0, ('C', 'e', 'f', 'g'): 4.0, ('A', 'e', 'f', 'g'): 4.0}
#
# These 1 paths were correctly detected (2 undetected):
# ['1: 123']
#
# These 10 paths are spurious:
# ['3: 3ABCD', '3: 2ABCD', '3: 1ABCD', '4: 3efg', '4: Defg', '4: 2efg', '4: Cefg', '4: Aefg', '4: Befg', '4: 1efg']

# %% [markdown]
# ## Multiple Trace Examples

# %%
T = [
    list("ABCD"),list("ABCD"),
    list("12345")
]
g, b = evaluate_against(T, ["ABCD", "12345"] )
# Out:
# Loops found:
# {}
#
# These 2 paths were correctly detected (0 undetected):
# ['1: 12345', '2: ABCD']
#
# These 0 paths are spurious:
# []

# %%
T = [
    list("ABCDABCD"),
    list("1234512345"),
    list("12345ABCD")
]
g, b = evaluate_against(T, ["ABCD", "12345"] )
# Out:
# Loops found:
# {('A', 'B', 'C', 'D'): 2.0, ('1', '2', '3', '4', '5'): 2.0}
#
# These 2 paths were correctly detected (0 undetected):
# ['3: 12345', '3: ABCD']
#
# These 20 paths are spurious:
# ['1: 3D', '1: 2D', '1: 5D', '1: 4D', '1: 1D', '1: 3B', '1: 2B', '1: 5B', '1: 4B', '1: 1B', '1: 3C', '1: 2C', '1: 5C', '1: 4C', '1: 1C', '1: 3A', '1: 2A', '1: 5A', '1: 4A', '1: 1A']

# %%
# Type 76-b
T = [
    list("ABCABCABC"),
    list("123123123123")
]
g, b = evaluate_against(T, ("ABC", "123") )
# Out:
# Loops found:
# {('A', 'B', 'C'): 3.0, ('1', '2', '3'): 4.0}
#
# These 2 paths were correctly detected (0 undetected):
# ['3: ABC', '4: 123']
#
# These 0 paths are spurious:
# []

# %% [markdown]
# Claim: all paths (cliques) forming a base are loops. Starting from max(f) -> min(f).

# %% [markdown]
# ### Examples from previous notebooks

# %%
# combined_loops: lk 12 ABCDE
T = [
    list("lklk1212ABCDEABCDEABCDE1212"),
    list("lk12ABCDEABCDE"),
    list("lk12ABCDE"),
]
g, b = evaluate_against(T, ("ABCDE", "lk", "12") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('l', 'k'): 2.0, ('A', 'B', 'C', 'D', 'E'): 5.0, ('l', 'A', 'B', 'C', 'D', 'E'): 3.0, ('k', 'A', 'B', 'C', 'D', 'E'): 3.0, ('1', '2'): 4.0}
#
# These 2 paths were correctly detected (1 undetected):
# ['4: lk', '6: 12']
#
# These 16 paths are spurious:
# ['10: l2', '10: l1', '10: k2', '10: k1', '3: 1D', '3: 1E', '3: 1C', '3: 1A', '3: 1B', '3: 2D', '3: 2E', '3: 2C', '3: 2A', '3: 2B', '6: lABCDE', '6: kABCDE']

# %%
"""
  @lk - @12 - @ABCDE
"""
T = [
    list("lklk1212ABCDEABCDEABCDE1212"),
    list("lk12ABCDEABCDE"),
    list("lk12ABCDE"),
]
g, b = evaluate_against(T, ["ABCDE", "lk", "12"] )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('l', 'k'): 2.0, ('A', 'B', 'C', 'D', 'E'): 5.0, ('l', 'A', 'B', 'C', 'D', 'E'): 3.0, ('k', 'A', 'B', 'C', 'D', 'E'): 3.0, ('1', '2'): 4.0}
#
# These 2 paths were correctly detected (1 undetected):
# ['4: lk', '6: 12']
#
# These 16 paths are spurious:
# ['10: l2', '10: l1', '10: k2', '10: k1', '3: 1D', '3: 1E', '3: 1C', '3: 1A', '3: 1B', '3: 2D', '3: 2E', '3: 2C', '3: 2A', '3: 2B', '6: lABCDE', '6: kABCDE']

# %%
"""
   ABC * 123        
"""
T = [ list(a) for a in ['ABC123', 'AB1C23', 'AB12C3', 'AB123C', 'A1BC23', 'A1B2C3', 'A1B23C', 
      'A12BC3', 'A12B3C', 'A123BC', '1ABC23', '1AB2C3', '1AB23C', '1A2BC3', 
      '1A2B3C', '1A23BC', '12ABC3', '12AB3C', '12A3BC', '123ABC'
]]
g, b = evaluate_against(T, ("ABC", "123") )
# Out:
# Loops found:
# {}
#
# These 2 paths were correctly detected (0 undetected):
# ['20: 123', '20: ABC']
#
# These 12 paths are spurious:
# ['1: 3A', '1: C1', '4: 3B', '4: B1', '4: C2', '4: 2A', '16: B3', '16: 1B', '16: 2C', '16: A2', '19: A3', '19: 1C']

# %%
"""
  @def 
       > FG 
  @hjk 
"""        
T = [
    list("defdefFG"),
    list("hjkhjkFG")
]
g, b = evaluate_against(T, ("hjk", "def", "FG") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('d', 'e', 'f'): 2.0, ('h', 'j', 'k'): 2.0}
#
# These 0 paths were correctly detected (3 undetected):
# []
#
# These 2 paths are spurious:
# ['2: hjkFG', '2: defFG']

# %%
"""
          hjk
  12345 <     > FG
          def 
"""
T = [
    list("12345defFG"),
    list("12345hjklFG")
]
g, b = evaluate_against(T, ("12345FG", "hjkl", "def") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {}
#
# These 1 paths were correctly detected (2 undetected):
# ['2: 12345FG']
#
# These 14 paths are spurious:
# ['1: 3def', '1: defF', '1: 2def', '1: 5def', '1: defG', '1: 4def', '1: 1def', '1: 3hjkl', '1: hjklF', '1: 2hjkl', '1: 5hjkl', '1: hjklG', '1: 4hjkl', '1: 1hjkl']

# %%
"""
          @hjk
  12345 <      > FG
          @def 
"""
T = [
    list("12345defdefFG"),
    list("12345hjkhjkFG")
]
g, b = evaluate_against(T, ["12345", "hjk", "def", "FG"] )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('d', 'e', 'f'): 2.0, ('h', 'j', 'k'): 2.0}
#
# These 0 paths were correctly detected (4 undetected):
# []
#
# These 2 paths are spurious:
# ['2: 12345hjkFG', '2: 12345defFG']

# %%
# loop_inside = @hjk | ( (12 | 34) - ABC - @def - FG) )
"""
                     
  @hjk ----------- 
                  \
   12               > FG
       > ABC - @def 
   34 
        
"""
T = [
    list("12ABCdefdefFG"),
    list("12ABCdefdefdefFG"),
    list("34ABCdefFG"),
    list("hjkhjkFG")
]
g, b = evaluate_against(T, ("ABC", "34", "12", "hjk", "def", "FG") )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('d', 'e', 'f'): 5.0, ('h', 'j', 'k'): 2.0}
#
# These 1 paths were correctly detected (5 undetected):
# ['4: FG']
#
# These 28 paths are spurious:
# ['1: 34e', '1: 34F', '1: 34C', '1: 34A', '1: 34f', '1: 34G', '1: 34d', '1: 34B', '2: hjkG', '2: hjkF', '2: 12F', '2: 12C', '2: 12A', '2: 12G', '2: 12B', '3: ABCG', '3: ABCF', '5: 2f', '5: 2e', '5: 2d', '5: 1f', '5: 1e', '5: 1d', '6: defF', '6: Cdef', '6: Adef', '6: defG', '6: Bdef']

# %%
tree_trace = [
    list("ABmn12"),
    list("ABmn56"),
    list("ABpq12"),
    list("ABpq56"),
    list("ABst12"),
    list("ABst56"),
]
# inferred_paths = clique_discovery.infer_paths_from_traces( tree_trace )
# untangled_graph( clique_discovery.minimally_connected_graph( inferred_paths ) , with_weigths=False )
g, b = evaluate_against(tree_trace, ["AB", "mn", "12", "pq", "st", "56"] )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {}
#
# These 1 paths were correctly detected (5 undetected):
# ['6: AB']
#
# These 34 paths are spurious:
# ['1: n2', '1: s2', '1: q2', '1: p2', '1: m2', '1: t2', '1: n5', '1: s5', '1: q5', '1: p5', '1: m5', '1: t5', '1: n6', '1: s6', '1: q6', '1: p6', '1: m6', '1: t6', '1: n1', '1: s1', '1: q1', '1: p1', '1: m1', '1: t1', '2: Amn', '2: Ast', '2: Apq', '2: Bmn', '2: Bst', '2: Bpq', '3: A56', '3: A12', '3: B56', '3: B12']

# %% [markdown]
# ## Still Failing. Still...

# %%
"""
          @hjk
  12345 <      > FG
          @def 
          @xyz
"""
T = [
    list("12345defdefxyzxyzFG"),
    list("12345xyzxyzhjkhjkFG"),
    list("12345hjkxyzxyzhjkdefdefFG"),

]
g, b = evaluate_against(T, ["12345FG", "hjk", "def", "xyz"] )
# Out:
# WARNING HERE! OJO AQUI!
#
#
# Loops found:
# {('x', 'y', 'z'): 6.0, ('d', 'e', 'f'): 4.0, ('h', 'j', 'k'): 4.0}
#
# These 1 paths were correctly detected (3 undetected):
# ['3: 12345FG']
#
# These 14 paths are spurious:
# ['4: 3hjkdef', '4: hjkdefF', '4: 2hjkdef', '4: 5hjkdef', '4: hjkdefG', '4: 4hjkdef', '4: 1hjkdef', '6: 3xyz', '6: xyzF', '6: 2xyz', '6: 5xyz', '6: xyzG', '6: 4xyz', '6: 1xyz']
