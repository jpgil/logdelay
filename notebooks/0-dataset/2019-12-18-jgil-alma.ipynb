# %% [markdown]
# # ALMA Dataset Generation

# %% [markdown]
# The dataset from ALMA correspond to some manually selected antenna containers that covers the full lifecycle of the related computer, between reboots.

# %%
# !ls ../../data/raw/alma | tail
# Out:
# dv25-acsStartContainer_cppContainer_2017-07-10_17.03.32.841
# dv25-acsStartContainer_cppContainer_2017-07-10_17.12.59.636
# dv25-acsStartContainer_cppContainer_2017-07-10_19.30.47.674
# dv25-acsStartContainer_cppContainer_2017-07-10_20.43.06.773
# dv25-acsStartContainer_cppContainer_2017-07-10_20.56.06.754
# dv25-acsStartContainer_cppContainer_2017-07-11_19.55.26.410
# dv25-acsStartContainer_cppContainer_2017-07-11_20.41.40.861
# dv25-acsStartContainer_cppContainer_2017-07-11_20.55.42.275
# dv25-acsStartContainer_cppContainer_2017-07-12_00.14.04.823
# dv25-acsStartContainer_cppContainer_2017-07-12_00.40.12.586

# %%
# !tail -n 5 ../../data/raw/alma/dv25-acsStartContainer_cppContainer_2017-07-10_17.03.32.841
# Out:
# 2017-07-10T17:09:35.050 [CONTROL/DV25/cppContainer-GL - virtual void AmbDeviceImpl::monitorEnc(ACS::Time*, const AMBSystem::AmbRelativeAddr&, AmbDataLength_t&, AmbDataMem_t*)] CAMB Error (type=10000, code=0) Detail="The monitor request returned an error.  AMB status = 11, channel = 1, node number = 0x13, RCA = 0xb009."
# terminate called after throwing an instance of 'St9bad_alloc'
#   what():  St9bad_alloc
# /alma/ACS-2015.8/ACSSW/bin/acsStartContainer: line 112:  3298 Aborted                 (core dumped) $COMMANDLINE
# 2017-07-10T17:09:48.100 INFO [acsStartContainer] Container: 'CONTROL/DV25/cppContainer' exited with code: 134.

# %% [markdown]
# ## Load an antenna file

# %% [markdown]
# Given an antenna file:

# %%
ant_file="../../data/raw/alma/da41-acsStartContainer_cppContainer_2017-07-10_00.15.06.909"

# %% [markdown]
# Let's consider only the individual lines that follows the rule:
# ```
# TIMESTAMP [Source] logtext
# ```
# The file is read in a pandas dataframe

# %%
import pandas as pd
RAWLINES=!cat $ant_file | egrep "^2[0-9]..\-..\-..T.*[0-9][0-9][0-9] \["
raw=pd.DataFrame(RAWLINES)

# %% [markdown]
# And it is splitted into different columns, removing some useless strings (as CONTROL/ANT)

# %%
import re
regex = re.compile(r"CONTROL\/[A-Z][A-Z][0-9][0-9]")

raw["@timestamp"] = raw[0].apply( lambda r: pd.to_datetime( r[:23] ))
raw["source"]  = raw[0].apply( lambda r: regex.sub( "", r[24:].split("]")[0][1:] ) )
raw["logtext"] = raw[0].apply( lambda r: " ".join(r[24:].split("] ")[1:]) )
del raw[0]

# %%
raw
# Out:
#                    @timestamp  \
# 0     2017-07-10 00:15:11.255
# 1     2017-07-10 00:15:11.260
# 2     2017-07-10 00:15:11.263
# 3     2017-07-10 00:15:11.783
# 4     2017-07-10 00:15:11.784
# ...                       ...
# 22079 2017-07-10 16:33:04.787
# 22080 2017-07-10 16:33:05.880
# 22081 2017-07-10 16:33:07.045
# 22082 2017-07-10 16:33:08.276
# 22083 2017-07-10 16:33:09.304
#
#                                                   source  \
# 0                        /cppContainer-GL - cdb::DAOImpl
# 1        /cppContainer - maci::ContainerImpl::getManager
# 2      /cppContainer-GL - maci::MACIHelper::resolveMa...
# 3                  /cppContainer - maci::Container::init
# 4              /cppContainer - maci::ContainerImpl::init
# ...                                                  ...
# 22079  /cppContainer-GL - void Control::DelayCalculat...
# 22080  /cppContainer-GL - void Control::DelayCalculat...
# 22081  /cppContainer-GL - void Control::DelayCalculat...
# 22082  /cppContainer-GL - void Control::DelayCalculat...
# 22083  /cppContainer-GL - void Control::DelayCalculat...
#
#                                                  logtext
# 0      DAO:'MACI/Containers/CONTROL/DA41/cppContainer...
# 1                                   Resolving manager...
# 2      ManagerReference obtained via command line: 'c...
# 3                                      Recovery enabled.
# 4       Container 'CONTROL/DA41/cppContainer' activated.
# ...                                                  ...
# 22079  Illegal Parameter Error (type=10000, code=2) D...
# 22080  Illegal Parameter Error (type=10000, code=2) D...
# 22081  Illegal Parameter Error (type=10000, code=2) D...
# 22082  Illegal Parameter Error (type=10000, code=2) D...
# 22083  Illegal Parameter Error (type=10000, code=2) D...
#
# [22084 rows x 3 columns]

# %% [markdown]
# ## Searching for Antenna Observing

# %% [markdown]
# From a previous work, we choose a high level task called "Antenna Observing" that are characterized by the following start / end events:
#
# ```
# Request to load 'AntInterferometryController'
# ...
# Switched state of component ... AntInterferometryController: DESTROYING -> DEFUNCT
# ```
# Let's search in

# %%
start = raw[ raw["logtext"].str.contains("Request to load.*AntInterferometryController", regex=True) ]
end = raw[ raw["logtext"].str.contains("AntInterferometryController: DESTROYING -> DEFUNCT", regex=False) ]

# %% [markdown]
# The events between those two  markers corresponds to AntennaObserving instances to be analyzed.

# %%
ant_obs=pd.DataFrame( { 'start': start["@timestamp"].values, 'end': end["@timestamp"].values })

# %%
ant_obs
# Out:
#                      start                     end
# 0  2017-07-10 00:38:38.588 2017-07-10 00:41:21.199
# 1  2017-07-10 00:42:11.811 2017-07-10 00:44:22.704
# 2  2017-07-10 01:04:21.772 2017-07-10 01:06:57.225
# 3  2017-07-10 01:07:56.474 2017-07-10 01:24:03.884
# 4  2017-07-10 01:24:35.320 2017-07-10 01:32:30.904
# 5  2017-07-10 01:36:19.689 2017-07-10 03:02:15.280
# 6  2017-07-10 03:03:01.875 2017-07-10 04:33:51.515
# 7  2017-07-10 04:34:21.718 2017-07-10 05:34:23.953
# 8  2017-07-10 05:34:57.171 2017-07-10 06:51:49.588
# 9  2017-07-10 06:52:27.492 2017-07-10 08:01:46.526
# 10 2017-07-10 08:02:32.387 2017-07-10 09:11:45.908
# 11 2017-07-10 09:12:34.736 2017-07-10 10:33:01.113
# 12 2017-07-10 10:33:46.244 2017-07-10 11:25:40.445
# 13 2017-07-10 11:35:29.013 2017-07-10 11:35:57.858
# 14 2017-07-10 11:42:15.192 2017-07-10 11:44:50.736
# 15 2017-07-10 11:54:56.997 2017-07-10 13:05:53.625

# %% [markdown]
# And now, let's filter the raw logs by the ant_obs dates

# %%
for i, r in ant_obs.iterrows():
    print( r["start"], len(raw[ raw["@timestamp"] >= r["start"] ][ raw["@timestamp"] <= r["end"] ]))
# Out:
# 2017-07-10 00:38:38.588000 121
# 2017-07-10 00:42:11.811000 69
# 2017-07-10 01:04:21.772000 92
# 2017-07-10 01:07:56.474000 276
# 2017-07-10 01:24:35.320000 206
# 2017-07-10 01:36:19.689000 605
# 2017-07-10 03:03:01.875000 397
# 2017-07-10 04:34:21.718000 222
# 2017-07-10 05:34:57.171000 232
# 2017-07-10 06:52:27.492000 532
# 2017-07-10 08:02:32.387000 516
# 2017-07-10 09:12:34.736000 712
# 2017-07-10 10:33:46.244000 442
# 2017-07-10 11:35:29.013000 52
# 2017-07-10 11:42:15.192000 114
# 2017-07-10 11:54:56.997000 446
# /Users/jgil/logdelay/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ## All Together

# %%
import pandas as pd
import re

def get_alma_logs(ant_file):
    RAWLINES=!cat $ant_file | egrep "^2[0-9]..\-..\-..T.*[0-9][0-9][0-9] \["
    raw=pd.DataFrame(RAWLINES)
    if len(raw) == 0:
        return []

    regex = re.compile(r"CONTROL\/[A-Z][A-Z][0-9][0-9]")

    raw["@timestamp"] = raw[0].apply( lambda r: pd.to_datetime( r[:23] ))
    raw["source"]  = raw[0].apply( lambda r: regex.sub( "", r[24:].split("]")[0][1:] ) )
    raw["logtext"] = raw[0].apply( lambda r: " ".join(r[24:].split("] ")[1:]) )
    del raw[0]
    
    start = raw[ raw["logtext"].str.contains("Request to load.*AntInterferometryController", regex=True) ]
    end = raw[ raw["logtext"].str.contains("AntInterferometryController: DESTROYING -> DEFUNCT", regex=False) ]
    
    minl = min(len(start), len(end))
    ant_obs=pd.DataFrame( { 'start': start[:minl]["@timestamp"].values, 'end': end[:minl]["@timestamp"].values })
    
    obs_logs = []
    for i, r in ant_obs.iterrows():
        obs_logs.append( raw[ raw["@timestamp"] >= r["start"] ][ raw["@timestamp"] <= r["end"] ] )
    
    return obs_logs

# %%
for logs in get_alma_logs("../../data/raw/alma/da41-acsStartContainer_cppContainer_2017-07-10_00.15.06.909"):
    print ( "At %s there are %s logs" % (logs[["@timestamp"]].values[0], len(logs)) )
# Out:
# At ['2017-07-10T00:38:38.588000000'] there are 121 logs
# At ['2017-07-10T00:42:11.811000000'] there are 69 logs
# At ['2017-07-10T01:04:21.772000000'] there are 92 logs
# At ['2017-07-10T01:07:56.474000000'] there are 276 logs
# At ['2017-07-10T01:24:35.320000000'] there are 206 logs
# At ['2017-07-10T01:36:19.689000000'] there are 605 logs
# At ['2017-07-10T03:03:01.875000000'] there are 397 logs
# At ['2017-07-10T04:34:21.718000000'] there are 222 logs
# At ['2017-07-10T05:34:57.171000000'] there are 232 logs
# At ['2017-07-10T06:52:27.492000000'] there are 532 logs
# At ['2017-07-10T08:02:32.387000000'] there are 516 logs
# At ['2017-07-10T09:12:34.736000000'] there are 712 logs
# At ['2017-07-10T10:33:46.244000000'] there are 442 logs
# At ['2017-07-10T11:35:29.013000000'] there are 52 logs
# At ['2017-07-10T11:42:15.192000000'] there are 114 logs
# At ['2017-07-10T11:54:56.997000000'] there are 446 logs
# /Users/jgil/logdelay/venv/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ## Storing ALMA datasets in INTERIM

# %%
FILES=!ls ../../data/raw/alma/

# %%
# !mkdir -p ../../data/interim/ALMA/
all_stats=[]
for f in FILES:
    alllogs = get_alma_logs("../../data/raw/alma/%s" % f)
    print("Processing %s with #%s logs" % (f, len(alllogs)))
    for logs in alllogs:
        stats={}
        stats["antenna"] = f[:4]
        stats["@timestamp"] = str(logs["@timestamp"][0:1].values[0])[:23]
        stats["# logs"] = len(logs)
        logs.to_csv("../../data/interim/ALMA/%s-%s-AntObs.csv" % (stats["@timestamp"], stats["antenna"]), index=False )
        
        all_stats.append(stats)
pstats=pd.DataFrame(all_stats)
pstats.to_csv("../../data/interim/ALMA/count-AntObs.csv", index=False)
pstats
# Out:
# Processing da41-acsStartContainer_cppContainer_2017-07-01_18.16.48.847 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-01_20.06.49.894 with #7 logs
# /Users/jgil/logdelay/venv/lib/python3.7/site-packages/ipykernel_launcher.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Processing da41-acsStartContainer_cppContainer_2017-07-01_22.45.35.715 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-03_20.37.03.645 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-03_21.43.00.460 with #2 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_19.22.44.226 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_19.44.33.199 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_19.56.28.307 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_21.11.36.377 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_21.12.49.008 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-05_21.51.45.672 with #4 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-07_20.39.24.481 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-07_21.01.00.244 with #3 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-10_00.15.06.909 with #16 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-10_16.41.42.710 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-10_17.03.21.896 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-10_19.30.53.992 with #2 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-11_19.55.20.766 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-11_20.41.42.314 with #2 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-12_00.14.00.201 with #0 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-12_00.40.21.648 with #32 logs
# Processing da41-acsStartContainer_cppContainer_2017-07-12_23.14.11.857 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-01_18.16.49.516 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-01_20.06.50.589 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-01_22.45.34.727 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-02_16.16.55.445 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-02_16.31.21.765 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-02_16.59.35.746 with #12 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-02_22.29.49.050 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-02_22.41.21.335 with #4 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-03_20.36.56.611 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-03_21.43.00.806 with #2 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_19.22.25.601 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_19.44.21.986 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_19.56.26.597 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_21.11.37.530 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_21.12.48.989 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-05_21.51.42.787 with #4 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-07_20.39.24.774 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-07_21.01.09.100 with #3 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-09_23.56.04.272 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_00.15.04.392 with #16 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_16.41.59.395 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_17.03.17.905 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_19.30.50.875 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_20.39.20.110 with #1 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-10_22.04.34.592 with #1 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-11_19.55.30.057 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-11_20.41.34.197 with #2 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-12_00.14.01.025 with #0 logs
# Processing da43-acsStartContainer_cppContainer_2017-07-12_00.40.16.537 with #32 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-01_18.17.04.386 with #2 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-01_20.07.03.521 with #7 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-01_22.45.31.558 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-03_20.37.01.665 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-03_21.43.03.417 with #2 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_19.22.26.123 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_19.44.32.640 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_19.56.31.927 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_21.11.36.661 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_21.12.48.989 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-05_21.51.46.068 with #4 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-07_20.39.24.708 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-07_21.00.59.001 with #3 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-09_23.55.57.778 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-10_00.15.06.635 with #16 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-10_16.41.47.704 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-10_17.03.19.374 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-10_19.30.52.892 with #2 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-11_19.55.29.359 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-11_20.41.39.309 with #2 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-12_00.14.03.595 with #0 logs
# Processing da44-acsStartContainer_cppContainer_2017-07-12_00.40.15.056 with #32 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-01_18.16.56.976 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-01_20.06.58.865 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-01_22.45.27.207 with #2 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-03_20.37.03.875 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-03_21.43.12.882 with #2 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_19.22.09.015 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_19.44.29.053 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_19.56.32.107 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_21.11.41.301 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_21.12.49.147 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-05_21.51.44.020 with #4 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-07_20.39.23.277 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-07_21.01.01.722 with #3 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-09_23.55.55.201 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-10_00.15.13.786 with #16 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-10_16.41.41.507 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-10_17.03.31.850 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-10_19.30.53.624 with #2 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-11_19.55.32.254 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-11_20.41.37.400 with #2 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-12_00.13.57.419 with #0 logs
# Processing da50-acsStartContainer_cppContainer_2017-07-12_00.40.24.928 with #14 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-01_18.16.52.203 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-01_20.06.54.680 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-01_22.45.35.556 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-03_20.36.59.873 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-03_21.43.10.448 with #1 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_19.22.28.957 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_19.44.28.167 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_19.56.28.140 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_21.11.39.995 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_21.12.49.145 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-05_21.51.43.941 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-07_18.35.35.663 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-07_20.39.23.639 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-07_21.01.00.218 with #2 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-07_22.36.02.272 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-10_00.15.13.519 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-10_16.41.59.283 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-10_17.03.30.439 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-10_19.30.50.051 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-11_19.55.33.965 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-11_20.41.38.918 with #2 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-12_00.14.02.194 with #0 logs
# Processing da52-acsStartContainer_cppContainer_2017-07-12_00.40.16.290 with #32 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-01_18.17.03.944 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-01_20.07.01.160 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-01_22.45.27.921 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-03_20.37.02.329 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-03_21.43.13.275 with #2 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_19.22.15.583 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_19.44.23.995 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_19.56.26.928 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_21.11.41.728 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_21.12.48.993 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-05_21.51.43.737 with #4 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-07_20.39.28.959 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-07_21.01.13.071 with #3 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-10_00.15.07.448 with #16 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-10_16.41.48.261 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-10_17.03.22.132 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-10_19.30.54.753 with #2 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-11_19.55.30.846 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-11_20.41.32.426 with #2 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-12_00.13.59.055 with #0 logs
# Processing da56-acsStartContainer_cppContainer_2017-07-12_00.40.13.443 with #32 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-01_18.16.49.049 with #2 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-01_20.06.49.958 with #7 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-01_22.45.36.985 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-03_20.36.54.607 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-03_21.43.01.851 with #2 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_19.22.44.235 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_19.44.28.745 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_19.56.32.156 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_21.11.41.092 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_21.12.48.993 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-05_21.51.36.801 with #4 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-07_20.39.22.672 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-07_21.01.00.675 with #3 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-09_23.56.04.159 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-10_00.15.06.379 with #16 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-10_16.41.55.944 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-10_17.03.18.552 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-10_19.30.53.100 with #2 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-11_19.55.31.381 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-11_20.41.42.251 with #2 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-12_00.14.02.682 with #0 logs
# Processing da62-acsStartContainer_cppContainer_2017-07-12_00.40.17.979 with #32 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-01_18.16.47.590 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-01_20.06.48.852 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-01_22.45.30.695 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-03_20.36.56.174 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-03_21.43.02.181 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-05_19.22.11.305 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-05_19.44.22.858 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-05_19.56.25.965 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-05_21.11.40.772 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-05_21.51.45.431 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-07_20.39.27.187 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-07_21.01.09.027 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-08_23.23.24.175 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-10_00.15.13.638 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-10_16.41.47.524 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-10_17.03.30.509 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-10_19.30.45.566 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-11_19.55.20.929 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-11_20.41.36.990 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-12_00.14.06.257 with #0 logs
# Processing da64-acsStartContainer_cppContainer_2017-07-12_00.40.16.668 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-01_18.16.56.614 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-01_20.06.58.503 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-01_22.45.27.481 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-03_20.36.58.181 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-03_21.42.59.841 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_19.22.24.388 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_19.44.30.108 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_19.56.23.599 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_21.11.40.415 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_21.12.49.143 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-05_21.51.43.793 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-07_20.39.23.425 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-07_21.01.13.755 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_00.15.07.941 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_16.41.50.218 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_17.03.30.932 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_17.53.30.131 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_18.29.36.632 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-10_19.30.48.851 with #1 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_12.29.33.241 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_12.45.20.756 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_13.32.35.667 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_13.50.11.581 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_14.26.14.880 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_19.55.26.552 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-11_20.41.42.578 with #2 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-12_00.14.02.922 with #0 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-12_00.40.19.571 with #5 logs
# Processing dv02-acsStartContainer_cppContainer_2017-07-12_16.28.50.242 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-01_18.16.48.051 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-01_20.06.49.300 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-01_22.45.40.930 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-02_16.47.08.465 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-03_20.36.55.029 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-03_21.43.13.185 with #1 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_19.22.25.082 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_19.44.27.201 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_19.56.30.147 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_21.11.34.183 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_21.12.49.142 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-05_21.51.43.099 with #1 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-07_20.39.22.312 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-07_21.01.13.000 with #5 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-09_23.55.53.034 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-10_00.15.12.232 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-10_18.26.03.486 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-10_19.30.51.766 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-11_19.55.30.123 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-11_20.41.34.552 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-12_00.14.03.722 with #0 logs
# Processing dv07-acsStartContainer_cppContainer_2017-07-12_00.40.12.540 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-01_18.16.52.999 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-01_20.06.55.149 with #7 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-01_22.45.33.484 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-03_20.36.59.377 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-03_21.43.02.446 with #2 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_19.22.22.035 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_19.44.21.729 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_19.56.31.481 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_21.11.40.358 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_21.12.49.027 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-05_21.51.46.139 with #4 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-07_20.39.27.038 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-07_21.00.58.894 with #4 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-10_00.15.15.006 with #16 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-10_16.41.45.937 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-10_17.03.19.773 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-10_19.30.50.429 with #2 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-11_19.55.34.553 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-11_20.41.39.377 with #2 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-12_00.13.59.015 with #0 logs
# Processing dv13-acsStartContainer_cppContainer_2017-07-12_00.40.21.087 with #32 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-01_18.17.03.539 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-01_20.07.00.790 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-01_22.45.32.937 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-03_20.36.58.974 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-03_21.43.02.772 with #2 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_19.22.24.689 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_19.44.33.393 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_19.56.32.973 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_21.11.37.892 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_21.12.49.143 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-05_21.51.39.520 with #4 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-07_20.39.21.919 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-07_21.01.08.711 with #3 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-09_23.55.52.178 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-10_00.15.05.098 with #16 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-10_16.41.51.021 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-10_17.03.27.320 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-10_19.30.54.202 with #2 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-11_19.55.33.839 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-11_20.41.38.256 with #2 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-12_00.13.56.440 with #0 logs
# Processing dv22-acsStartContainer_cppContainer_2017-07-12_00.40.17.993 with #32 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-03_18.59.31.399 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-03_20.37.01.535 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-03_21.43.00.125 with #1 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-03_23.36.20.966 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-04_00.03.34.418 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_19.22.13.541 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_19.44.21.593 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_19.56.29.316 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_21.11.38.913 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_21.12.49.039 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-05_21.51.43.910 with #1 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-07_20.39.29.447 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-07_21.01.05.943 with #3 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-09_23.56.03.359 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_00.15.05.878 with #16 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_16.41.47.461 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_17.03.32.841 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_17.12.59.636 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_19.30.47.674 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_20.43.06.773 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-10_20.56.06.754 with #2 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-11_19.55.26.410 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-11_20.41.40.861 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-11_20.55.42.275 with #2 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-12_00.14.04.823 with #0 logs
# Processing dv25-acsStartContainer_cppContainer_2017-07-12_00.40.12.586 with #32 logs
#     antenna               @timestamp  # logs
# 0      da41  2017-07-01T21:02:13.979      18
# 1      da41  2017-07-01T21:03:21.631      19
# 2      da41  2017-07-01T21:20:08.150      41
# 3      da41  2017-07-01T21:23:26.907     341
# 4      da41  2017-07-01T21:37:25.567     314
# ..      ...                      ...     ...
# 625    dv25  2017-07-12T11:02:24.567     273
# 626    dv25  2017-07-12T12:24:18.011     206
# 627    dv25  2017-07-12T12:54:40.157     963
# 628    dv25  2017-07-12T14:39:02.679     933
# 629    dv25  2017-07-12T16:09:50.047     881
#
# [630 rows x 3 columns]
